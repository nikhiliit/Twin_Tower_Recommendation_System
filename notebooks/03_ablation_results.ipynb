# %% [markdown]
# # Ablation Results
#
# Compare and visualize results across loss function experiments:
# - Ablation table
# - Training curves
# - Cold-start analysis
# - Latency benchmarks

# %%
import mlflow
import pandas as pd
import matplotlib.pyplot as plt

mlflow.set_tracking_uri('mlruns/')
experiment = mlflow.get_experiment_by_name('two_tower_retrieval')
runs = mlflow.search_runs(experiment.experiment_id)
print(runs[['run_id', 'params.experiment.name', 'metrics.test_recall_at_50']])
